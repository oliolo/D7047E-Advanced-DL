# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(optimizer=Adam(0.01),loss = BinaryCrossentropy(),metrics=['accuracy'])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 77s 5s/step - loss: 1.1515 - accuracy: 0.5124 - val_loss: 0.7148 - val_accuracy: 0.4701
# Epoch 2/20
# 15/15 [==============================] - 139s 9s/step - loss: 0.6640 - accuracy: 0.6118 - val_loss: 0.6431 - val_accuracy: 0.6333
# Epoch 3/20
# 15/15 [==============================] - 306s 20s/step - loss: 0.5774 - accuracy: 0.7090 - val_loss: 0.5874 - val_accuracy: 0.6877
# Epoch 4/20
# 15/15 [==============================] - 363s 24s/step - loss: 0.5525 - accuracy: 0.7240 - val_loss: 0.5894 - val_accuracy: 0.6823
# Epoch 5/20
# 15/15 [==============================] - 362s 24s/step - loss: 0.5101 - accuracy: 0.7547 - val_loss: 0.6595 - val_accuracy: 0.6616
# Epoch 6/20
# 15/15 [==============================] - 369s 25s/step - loss: 0.5362 - accuracy: 0.7308 - val_loss: 0.5171 - val_accuracy: 0.7160
# Epoch 7/20
# 15/15 [==============================] - 362s 24s/step - loss: 0.5054 - accuracy: 0.7446 - val_loss: 0.5143 - val_accuracy: 0.7160
# Epoch 8/20
# 15/15 [==============================] - 371s 25s/step - loss: 0.4596 - accuracy: 0.7800 - val_loss: 0.4928 - val_accuracy: 0.7715
# Epoch 9/20
# 15/15 [==============================] - 257s 17s/step - loss: 0.4561 - accuracy: 0.7908 - val_loss: 0.5293 - val_accuracy: 0.7454
# Epoch 10/20
# 15/15 [==============================] - 165s 11s/step - loss: 0.4257 - accuracy: 0.8022 - val_loss: 0.4865 - val_accuracy: 0.7519
# Epoch 11/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.4139 - accuracy: 0.8074 - val_loss: 0.4212 - val_accuracy: 0.7954
# Epoch 12/20
# 15/15 [==============================] - 159s 11s/step - loss: 0.3815 - accuracy: 0.8408 - val_loss: 0.4696 - val_accuracy: 0.7726
# Epoch 13/20
# 15/15 [==============================] - 159s 11s/step - loss: 0.3853 - accuracy: 0.8231 - val_loss: 0.5328 - val_accuracy: 0.7280
# Epoch 14/20
# 15/15 [==============================] - 159s 11s/step - loss: 0.3534 - accuracy: 0.8419 - val_loss: 0.3936 - val_accuracy: 0.8215
# Epoch 15/20
# 15/15 [==============================] - 150s 10s/step - loss: 0.3321 - accuracy: 0.8530 - val_loss: 0.4584 - val_accuracy: 0.7867
# Epoch 16/20
# 15/15 [==============================] - 159s 11s/step - loss: 0.3044 - accuracy: 0.8691 - val_loss: 0.3482 - val_accuracy: 0.8498
# Epoch 17/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.3069 - accuracy: 0.8661 - val_loss: 0.4180 - val_accuracy: 0.8085
# Epoch 18/20
# 15/15 [==============================] - 166s 11s/step - loss: 0.3144 - accuracy: 0.8644 - val_loss: 0.3413 - val_accuracy: 0.8346
# Epoch 19/20
# 15/15 [==============================] - 170s 11s/step - loss: 0.2812 - accuracy: 0.8816 - val_loss: 0.4773 - val_accuracy: 0.8020
# Epoch 20/20
# 15/15 [==============================] - 172s 11s/step - loss: 0.2961 - accuracy: 0.8720 - val_loss: 0.5959 - val_accuracy: 0.7323

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 998us/step - loss: 0.6221 - accuracy: 0.6776
