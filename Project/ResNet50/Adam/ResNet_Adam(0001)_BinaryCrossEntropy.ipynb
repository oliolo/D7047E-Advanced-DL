# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(optimizer=Adam(0.0001),loss = BinaryCrossentropy(),metrics=['accuracy'])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 296s 20s/step - loss: 0.6799 - accuracy: 0.5702 - val_loss: 0.6548 - val_accuracy: 0.6083
# Epoch 2/20
# 15/15 [==============================] - 363s 24s/step - loss: 0.6459 - accuracy: 0.6438 - val_loss: 0.6319 - val_accuracy: 0.6474
# Epoch 3/20
# 15/15 [==============================] - 365s 24s/step - loss: 0.6197 - accuracy: 0.6860 - val_loss: 0.6162 - val_accuracy: 0.6561
# Epoch 4/20
# 15/15 [==============================] - 370s 25s/step - loss: 0.6027 - accuracy: 0.6963 - val_loss: 0.6154 - val_accuracy: 0.6583
# Epoch 5/20
# 15/15 [==============================] - 359s 24s/step - loss: 0.5915 - accuracy: 0.6998 - val_loss: 0.6094 - val_accuracy: 0.6572
# Epoch 6/20
# 15/15 [==============================] - 369s 25s/step - loss: 0.5869 - accuracy: 0.7047 - val_loss: 0.6037 - val_accuracy: 0.6627
# Epoch 7/20
# 15/15 [==============================] - 281s 19s/step - loss: 0.5729 - accuracy: 0.7128 - val_loss: 0.5964 - val_accuracy: 0.6659
# Epoch 8/20
# 15/15 [==============================] - 170s 11s/step - loss: 0.5654 - accuracy: 0.7245 - val_loss: 0.5897 - val_accuracy: 0.6714
# Epoch 9/20
# 15/15 [==============================] - 163s 11s/step - loss: 0.5574 - accuracy: 0.7330 - val_loss: 0.5869 - val_accuracy: 0.6768
# Epoch 10/20
# 15/15 [==============================] - 170s 11s/step - loss: 0.5509 - accuracy: 0.7335 - val_loss: 0.5785 - val_accuracy: 0.6823
# Epoch 11/20
# 15/15 [==============================] - 157s 10s/step - loss: 0.5465 - accuracy: 0.7340 - val_loss: 0.5938 - val_accuracy: 0.6649
# Epoch 12/20
# 15/15 [==============================] - 162s 11s/step - loss: 0.5392 - accuracy: 0.7354 - val_loss: 0.5768 - val_accuracy: 0.6801
# Epoch 13/20
# 15/15 [==============================] - 150s 10s/step - loss: 0.5331 - accuracy: 0.7416 - val_loss: 0.5638 - val_accuracy: 0.6953
# Epoch 14/20
# 15/15 [==============================] - 170s 11s/step - loss: 0.5272 - accuracy: 0.7438 - val_loss: 0.5624 - val_accuracy: 0.6997
# Epoch 15/20
# 15/15 [==============================] - 166s 11s/step - loss: 0.5231 - accuracy: 0.7539 - val_loss: 0.5527 - val_accuracy: 0.7084
# Epoch 16/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.5158 - accuracy: 0.7582 - val_loss: 0.5582 - val_accuracy: 0.7084
# Epoch 17/20
# 15/15 [==============================] - 162s 11s/step - loss: 0.5126 - accuracy: 0.7639 - val_loss: 0.5618 - val_accuracy: 0.7051
# Epoch 18/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.5090 - accuracy: 0.7645 - val_loss: 0.5383 - val_accuracy: 0.7214
# Epoch 19/20
# 15/15 [==============================] - 125s 8s/step - loss: 0.5011 - accuracy: 0.7680 - val_loss: 0.5340 - val_accuracy: 0.7247
# Epoch 20/20
# 15/15 [==============================] - 112s 7s/step - loss: 0.4983 - accuracy: 0.7634 - val_loss: 0.5331 - val_accuracy: 0.7367

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.5066 - accuracy: 0.7878
