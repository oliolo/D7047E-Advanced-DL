# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(optimizer=Adam(0.0001),loss = MeanSquaredError(),metrics=['accuracy'])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 132s 9s/step - loss: 0.2486 - accuracy: 0.5363 - val_loss: 0.2367 - val_accuracy: 0.6485
# Epoch 2/20
# 15/15 [==============================] - 128s 9s/step - loss: 0.2297 - accuracy: 0.6553 - val_loss: 0.2304 - val_accuracy: 0.6181
# Epoch 3/20
# 15/15 [==============================] - 138s 9s/step - loss: 0.2195 - accuracy: 0.6808 - val_loss: 0.2231 - val_accuracy: 0.6202
# Epoch 4/20
# 15/15 [==============================] - 141s 9s/step - loss: 0.2126 - accuracy: 0.6908 - val_loss: 0.2195 - val_accuracy: 0.6268
# Epoch 5/20
# 15/15 [==============================] - 132s 9s/step - loss: 0.2068 - accuracy: 0.7052 - val_loss: 0.2143 - val_accuracy: 0.6464
# Epoch 6/20
# 15/15 [==============================] - 127s 8s/step - loss: 0.2004 - accuracy: 0.7101 - val_loss: 0.2111 - val_accuracy: 0.6572
# Epoch 7/20
# 15/15 [==============================] - 128s 9s/step - loss: 0.1977 - accuracy: 0.7126 - val_loss: 0.2079 - val_accuracy: 0.6572
# Epoch 8/20
# 15/15 [==============================] - 127s 8s/step - loss: 0.1932 - accuracy: 0.7335 - val_loss: 0.2061 - val_accuracy: 0.6605
# Epoch 9/20
# 15/15 [==============================] - 127s 8s/step - loss: 0.1900 - accuracy: 0.7294 - val_loss: 0.2036 - val_accuracy: 0.6757
# Epoch 10/20
# 15/15 [==============================] - 135s 9s/step - loss: 0.1871 - accuracy: 0.7346 - val_loss: 0.2040 - val_accuracy: 0.6649
# Epoch 11/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.1865 - accuracy: 0.7316 - val_loss: 0.2030 - val_accuracy: 0.6681
# Epoch 12/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.1820 - accuracy: 0.7414 - val_loss: 0.1979 - val_accuracy: 0.6931
# Epoch 13/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.1791 - accuracy: 0.7460 - val_loss: 0.1961 - val_accuracy: 0.6964
# Epoch 14/20
# 15/15 [==============================] - 118s 8s/step - loss: 0.1760 - accuracy: 0.7465 - val_loss: 0.1928 - val_accuracy: 0.6921
# Epoch 15/20
# 15/15 [==============================] - 118s 8s/step - loss: 0.1757 - accuracy: 0.7493 - val_loss: 0.1896 - val_accuracy: 0.7062
# Epoch 16/20
# 15/15 [==============================] - 117s 8s/step - loss: 0.1720 - accuracy: 0.7574 - val_loss: 0.1888 - val_accuracy: 0.7062
# Epoch 17/20
# 15/15 [==============================] - 123s 8s/step - loss: 0.1703 - accuracy: 0.7593 - val_loss: 0.1850 - val_accuracy: 0.7203
# Epoch 18/20
# 15/15 [==============================] - 118s 8s/step - loss: 0.1699 - accuracy: 0.7601 - val_loss: 0.1834 - val_accuracy: 0.7193
# Epoch 19/20
# 15/15 [==============================] - 122s 8s/step - loss: 0.1654 - accuracy: 0.7723 - val_loss: 0.1812 - val_accuracy: 0.7247
# Epoch 20/20
# 15/15 [==============================] - 119s 8s/step - loss: 0.1644 - accuracy: 0.7721 - val_loss: 0.1791 - val_accuracy: 0.7258

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.7592
