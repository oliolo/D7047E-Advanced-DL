# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import MeanSquaredError
from keras.optimizers import Adam
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(optimizer=Adam(0.001),loss = MeanSquaredError(),metrics=['accuracy'])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11214976
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 11,243,457
# Trainable params: 11,243,073
# Non-trainable params: 384
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 59s 4s/step - loss: 0.2059 - accuracy: 0.7109 - val_loss: 0.1993 - val_accuracy: 0.7367
# Epoch 2/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1144 - accuracy: 0.8424 - val_loss: 0.1208 - val_accuracy: 0.8368
# Epoch 3/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0624 - accuracy: 0.9218 - val_loss: 0.1110 - val_accuracy: 0.8727
# Epoch 4/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0363 - accuracy: 0.9573 - val_loss: 0.1089 - val_accuracy: 0.8825
# Epoch 5/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0241 - accuracy: 0.9745 - val_loss: 0.0878 - val_accuracy: 0.9282
# Epoch 6/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0159 - accuracy: 0.9864 - val_loss: 0.0506 - val_accuracy: 0.9880
# Epoch 7/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.0102 - accuracy: 0.9908 - val_loss: 0.0436 - val_accuracy: 0.9848
# Epoch 8/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0068 - accuracy: 0.9946 - val_loss: 0.0394 - val_accuracy: 0.9924
# Epoch 9/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0049 - accuracy: 0.9970 - val_loss: 0.0308 - val_accuracy: 0.9913
# Epoch 10/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0043 - accuracy: 0.9965 - val_loss: 0.0251 - val_accuracy: 0.9913
# Epoch 11/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.0048 - accuracy: 0.9962 - val_loss: 0.0410 - val_accuracy: 0.9630
# Epoch 12/20
# 15/15 [==============================] - 58s 4s/step - loss: 0.0039 - accuracy: 0.9967 - val_loss: 0.0134 - val_accuracy: 0.9967
# Epoch 13/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.0030 - accuracy: 0.9981 - val_loss: 0.0321 - val_accuracy: 0.9684
# Epoch 14/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.0027 - accuracy: 0.9981 - val_loss: 0.0136 - val_accuracy: 0.9902
# Epoch 15/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.0022 - accuracy: 0.9986 - val_loss: 0.0139 - val_accuracy: 0.9902
# Epoch 16/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0021 - accuracy: 0.9984 - val_loss: 0.0220 - val_accuracy: 0.9826
# Epoch 17/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.0025 - accuracy: 0.9981 - val_loss: 0.0132 - val_accuracy: 0.9891
# Epoch 18/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.0083 - val_accuracy: 0.9913
# Epoch 19/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.0015 - accuracy: 0.9989 - val_loss: 0.0068 - val_accuracy: 0.9946
# Epoch 20/20
# 15/15 [==============================] - 52s 3s/step - loss: 0.0014 - accuracy: 0.9989 - val_loss: 0.0044 - val_accuracy: 0.9956

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.0046 - accuracy: 0.9959
