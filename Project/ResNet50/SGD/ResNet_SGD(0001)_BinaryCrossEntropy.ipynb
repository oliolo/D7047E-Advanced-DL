# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import BinaryCrossentropy
from keras.optimizers import SGD
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(loss=BinaryCrossentropy(), optimizer=SGD(0.0001), metrics=["accuracy"])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.7690 - accuracy: 0.4675 - val_loss: 0.7113 - val_accuracy: 0.4538
# Epoch 2/20
# 15/15 [==============================] - 210s 14s/step - loss: 0.7073 - accuracy: 0.5012 - val_loss: 0.6953 - val_accuracy: 0.4538
# Epoch 3/20
# 15/15 [==============================] - 213s 14s/step - loss: 0.7006 - accuracy: 0.5099 - val_loss: 0.6922 - val_accuracy: 0.5354
# Epoch 4/20
# 15/15 [==============================] - 201s 13s/step - loss: 0.6971 - accuracy: 0.5238 - val_loss: 0.6905 - val_accuracy: 0.5462
# Epoch 5/20
# 15/15 [==============================] - 215s 14s/step - loss: 0.6925 - accuracy: 0.5422 - val_loss: 0.6894 - val_accuracy: 0.5560
# Epoch 6/20
# 15/15 [==============================] - 214s 14s/step - loss: 0.6938 - accuracy: 0.5276 - val_loss: 0.6883 - val_accuracy: 0.5680
# Epoch 7/20
# 15/15 [==============================] - 205s 14s/step - loss: 0.6952 - accuracy: 0.5249 - val_loss: 0.6875 - val_accuracy: 0.5745
# Epoch 8/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.6924 - accuracy: 0.5330 - val_loss: 0.6866 - val_accuracy: 0.5756
# Epoch 9/20
# 15/15 [==============================] - 121s 8s/step - loss: 0.6891 - accuracy: 0.5501 - val_loss: 0.6859 - val_accuracy: 0.5822
# Epoch 10/20
# 15/15 [==============================] - 121s 8s/step - loss: 0.6843 - accuracy: 0.5564 - val_loss: 0.6851 - val_accuracy: 0.5854
# Epoch 11/20
# 15/15 [==============================] - 114s 8s/step - loss: 0.6820 - accuracy: 0.5591 - val_loss: 0.6843 - val_accuracy: 0.5865
# Epoch 12/20
# 15/15 [==============================] - 113s 8s/step - loss: 0.6812 - accuracy: 0.5553 - val_loss: 0.6834 - val_accuracy: 0.5919
# Epoch 13/20
# 15/15 [==============================] - 110s 7s/step - loss: 0.6860 - accuracy: 0.5515 - val_loss: 0.6826 - val_accuracy: 0.5952
# Epoch 14/20
# 15/15 [==============================] - 111s 7s/step - loss: 0.6824 - accuracy: 0.5710 - val_loss: 0.6819 - val_accuracy: 0.5985
# Epoch 15/20
# 15/15 [==============================] - 111s 7s/step - loss: 0.6792 - accuracy: 0.5637 - val_loss: 0.6812 - val_accuracy: 0.6007
# Epoch 16/20
# 15/15 [==============================] - 112s 7s/step - loss: 0.6785 - accuracy: 0.5767 - val_loss: 0.6807 - val_accuracy: 0.6007
# Epoch 17/20
# 15/15 [==============================] - 114s 8s/step - loss: 0.6792 - accuracy: 0.5713 - val_loss: 0.6802 - val_accuracy: 0.6050
# Epoch 18/20
# 15/15 [==============================] - 115s 8s/step - loss: 0.6786 - accuracy: 0.5719 - val_loss: 0.6800 - val_accuracy: 0.6017
# Epoch 19/20
# 15/15 [==============================] - 114s 8s/step - loss: 0.6758 - accuracy: 0.5797 - val_loss: 0.6793 - val_accuracy: 0.6028
# Epoch 20/20
# 15/15 [==============================] - 115s 8s/step - loss: 0.6745 - accuracy: 0.5933 - val_loss: 0.6790 - val_accuracy: 0.6137

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.6643 - accuracy: 0.6408
