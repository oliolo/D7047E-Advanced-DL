# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import MeanSquaredError
from keras.optimizers import SGD
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(loss=MeanSquaredError(), optimizer=SGD(0.0001), metrics=["accuracy"])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 225s 15s/step - loss: 0.2625 - accuracy: 0.5403 - val_loss: 0.2528 - val_accuracy: 0.5462
# Epoch 2/20
# 15/15 [==============================] - 232s 15s/step - loss: 0.2586 - accuracy: 0.5352 - val_loss: 0.2491 - val_accuracy: 0.5462
# Epoch 3/20
# 15/15 [==============================] - 218s 15s/step - loss: 0.2552 - accuracy: 0.5297 - val_loss: 0.2474 - val_accuracy: 0.5462
# Epoch 4/20
# 15/15 [==============================] - 168s 11s/step - loss: 0.2539 - accuracy: 0.5327 - val_loss: 0.2463 - val_accuracy: 0.5462
# Epoch 5/20
# 15/15 [==============================] - 168s 11s/step - loss: 0.2533 - accuracy: 0.5268 - val_loss: 0.2458 - val_accuracy: 0.5462
# Epoch 6/20
# 15/15 [==============================] - 167s 11s/step - loss: 0.2517 - accuracy: 0.5289 - val_loss: 0.2455 - val_accuracy: 0.5462
# Epoch 7/20
# 15/15 [==============================] - 154s 10s/step - loss: 0.2500 - accuracy: 0.5379 - val_loss: 0.2453 - val_accuracy: 0.5462
# Epoch 8/20
# 15/15 [==============================] - 150s 10s/step - loss: 0.2516 - accuracy: 0.5327 - val_loss: 0.2451 - val_accuracy: 0.5462
# Epoch 9/20
# 15/15 [==============================] - 163s 11s/step - loss: 0.2499 - accuracy: 0.5360 - val_loss: 0.2449 - val_accuracy: 0.5462
# Epoch 10/20
# 15/15 [==============================] - 167s 11s/step - loss: 0.2498 - accuracy: 0.5401 - val_loss: 0.2448 - val_accuracy: 0.5473
# Epoch 11/20
# 15/15 [==============================] - 119s 8s/step - loss: 0.2488 - accuracy: 0.5444 - val_loss: 0.2447 - val_accuracy: 0.5473
# Epoch 12/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2501 - accuracy: 0.5393 - val_loss: 0.2447 - val_accuracy: 0.5473
# Epoch 13/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2479 - accuracy: 0.5420 - val_loss: 0.2446 - val_accuracy: 0.5473
# Epoch 14/20
# 15/15 [==============================] - 115s 8s/step - loss: 0.2480 - accuracy: 0.5499 - val_loss: 0.2445 - val_accuracy: 0.5473
# Epoch 15/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2499 - accuracy: 0.5452 - val_loss: 0.2444 - val_accuracy: 0.5473
# Epoch 16/20
# 15/15 [==============================] - 121s 8s/step - loss: 0.2495 - accuracy: 0.5488 - val_loss: 0.2443 - val_accuracy: 0.5484
# Epoch 17/20
# 15/15 [==============================] - 117s 8s/step - loss: 0.2469 - accuracy: 0.5466 - val_loss: 0.2442 - val_accuracy: 0.5506
# Epoch 18/20
# 15/15 [==============================] - 115s 8s/step - loss: 0.2488 - accuracy: 0.5469 - val_loss: 0.2442 - val_accuracy: 0.5495
# Epoch 19/20
# 15/15 [==============================] - 120s 8s/step - loss: 0.2465 - accuracy: 0.5542 - val_loss: 0.2442 - val_accuracy: 0.5506
# Epoch 20/20
# 15/15 [==============================] - 66s 4s/step - loss: 0.2457 - accuracy: 0.5575 - val_loss: 0.2441 - val_accuracy: 0.5517

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.2348 - accuracy: 0.6367
