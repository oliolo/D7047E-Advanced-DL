# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import MeanSquaredError
from keras.optimizers import SGD
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(loss=MeanSquaredError(), optimizer=SGD(0.001), metrics=["accuracy"])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 185s 12s/step - loss: 0.2488 - accuracy: 0.5376 - val_loss: 0.2506 - val_accuracy: 0.5277
# Epoch 2/20
# 15/15 [==============================] - 216s 14s/step - loss: 0.2452 - accuracy: 0.5651 - val_loss: 0.2481 - val_accuracy: 0.5593
# Epoch 3/20
# 15/15 [==============================] - 212s 14s/step - loss: 0.2401 - accuracy: 0.5882 - val_loss: 0.2462 - val_accuracy: 0.5702
# Epoch 4/20
# 15/15 [==============================] - 221s 15s/step - loss: 0.2390 - accuracy: 0.5998 - val_loss: 0.2448 - val_accuracy: 0.5800
# Epoch 5/20
# 15/15 [==============================] - 160s 11s/step - loss: 0.2378 - accuracy: 0.5939 - val_loss: 0.2433 - val_accuracy: 0.5854
# Epoch 6/20
# 15/15 [==============================] - 166s 11s/step - loss: 0.2347 - accuracy: 0.6273 - val_loss: 0.2421 - val_accuracy: 0.5952
# Epoch 7/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.2334 - accuracy: 0.6297 - val_loss: 0.2408 - val_accuracy: 0.6050
# Epoch 8/20
# 15/15 [==============================] - 152s 10s/step - loss: 0.2306 - accuracy: 0.6390 - val_loss: 0.2395 - val_accuracy: 0.5952
# Epoch 9/20
# 15/15 [==============================] - 148s 10s/step - loss: 0.2303 - accuracy: 0.6419 - val_loss: 0.2379 - val_accuracy: 0.6017
# Epoch 10/20
# 15/15 [==============================] - 167s 11s/step - loss: 0.2293 - accuracy: 0.6487 - val_loss: 0.2381 - val_accuracy: 0.5865
# Epoch 11/20
# 15/15 [==============================] - 174s 12s/step - loss: 0.2259 - accuracy: 0.6653 - val_loss: 0.2359 - val_accuracy: 0.6007
# Epoch 12/20
# 15/15 [==============================] - 125s 8s/step - loss: 0.2254 - accuracy: 0.6580 - val_loss: 0.2342 - val_accuracy: 0.6017
# Epoch 13/20
# 15/15 [==============================] - 118s 8s/step - loss: 0.2239 - accuracy: 0.6596 - val_loss: 0.2340 - val_accuracy: 0.5985
# Epoch 14/20
# 15/15 [==============================] - 121s 8s/step - loss: 0.2226 - accuracy: 0.6648 - val_loss: 0.2320 - val_accuracy: 0.6104
# Epoch 15/20
# 15/15 [==============================] - 117s 8s/step - loss: 0.2219 - accuracy: 0.6683 - val_loss: 0.2310 - val_accuracy: 0.6170
# Epoch 16/20
# 15/15 [==============================] - 117s 8s/step - loss: 0.2202 - accuracy: 0.6794 - val_loss: 0.2302 - val_accuracy: 0.6137
# Epoch 17/20
# 15/15 [==============================] - 121s 8s/step - loss: 0.2189 - accuracy: 0.6802 - val_loss: 0.2293 - val_accuracy: 0.6213
# Epoch 18/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2177 - accuracy: 0.6770 - val_loss: 0.2302 - val_accuracy: 0.6104
# Epoch 19/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2178 - accuracy: 0.6754 - val_loss: 0.2287 - val_accuracy: 0.6202
# Epoch 20/20
# 15/15 [==============================] - 116s 8s/step - loss: 0.2164 - accuracy: 0.6860 - val_loss: 0.2280 - val_accuracy: 0.6202

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.2111 - accuracy: 0.6816
