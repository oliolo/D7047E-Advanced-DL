# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten, Input
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.applications.resnet50 import ResNet50
from keras.models import Sequential
from tensorflow.keras import layers

# %%
input_tensor = Input(shape=(100, 100, 3))  # this assumes K.image_data_format() == 'channels_last'

resnet_model = ResNet50(input_tensor=input_tensor,weights='imagenet', include_top=False)

for layer in resnet_model.layers:
    layer.trainable=False

resnet = Sequential()
resnet.add(resnet_model)
resnet.add(layers.Conv2D(32, kernel_size=(3,3), strides=(3,3), activation='relu', padding='same', input_shape=(100, 100, 1)))
resnet.add(layers.ReLU())
resnet.add(layers.MaxPooling2D(pool_size=(2,2)))
resnet.add(layers.Flatten())
resnet.add(layers.Dense(activation='relu', units=64))
resnet.add(layers.Dropout(0.2))
resnet.add(layers.Dense(activation='sigmoid', units=1))

resnet.compile(optimizer=Adam(0.001),loss = BinaryCrossentropy(),metrics=['accuracy'])

resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 4, 4, 2048)        23587712
# _________________________________________________________________
# conv2d (Conv2D)              (None, 2, 2, 32)          589856
# _________________________________________________________________
# re_lu (ReLU)                 (None, 2, 2, 32)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 24,179,745
# Trainable params: 592,033
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = resnet.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 190s 13s/step - loss: 0.6588 - accuracy: 0.6017 - val_loss: 0.6384 - val_accuracy: 0.6485
# Epoch 2/20
# 15/15 [==============================] - 339s 23s/step - loss: 0.5974 - accuracy: 0.6816 - val_loss: 0.5986 - val_accuracy: 0.6790
# Epoch 3/20
# 15/15 [==============================] - 372s 25s/step - loss: 0.5538 - accuracy: 0.7359 - val_loss: 0.5814 - val_accuracy: 0.6942
# Epoch 4/20
# 15/15 [==============================] - 367s 24s/step - loss: 0.5265 - accuracy: 0.7482 - val_loss: 0.5721 - val_accuracy: 0.7160
# Epoch 5/20
# 15/15 [==============================] - 377s 25s/step - loss: 0.5208 - accuracy: 0.7474 - val_loss: 0.5367 - val_accuracy: 0.7149
# Epoch 6/20
# 15/15 [==============================] - 367s 24s/step - loss: 0.4917 - accuracy: 0.7639 - val_loss: 0.5262 - val_accuracy: 0.7584
# Epoch 7/20
# 15/15 [==============================] - 355s 24s/step - loss: 0.4563 - accuracy: 0.7960 - val_loss: 0.5312 - val_accuracy: 0.7541
# Epoch 8/20
# 15/15 [==============================] - 219s 15s/step - loss: 0.4455 - accuracy: 0.7933 - val_loss: 0.5199 - val_accuracy: 0.7530
# Epoch 9/20
# 15/15 [==============================] - 178s 12s/step - loss: 0.4404 - accuracy: 0.7903 - val_loss: 0.4586 - val_accuracy: 0.7824
# Epoch 10/20
# 15/15 [==============================] - 175s 12s/step - loss: 0.4068 - accuracy: 0.8202 - val_loss: 0.4476 - val_accuracy: 0.7943
# Epoch 11/20
# 15/15 [==============================] - 161s 11s/step - loss: 0.4126 - accuracy: 0.8063 - val_loss: 0.4412 - val_accuracy: 0.8020
# Epoch 12/20
# 15/15 [==============================] - 158s 11s/step - loss: 0.3764 - accuracy: 0.8405 - val_loss: 0.4220 - val_accuracy: 0.8085
# Epoch 13/20
# 15/15 [==============================] - 157s 10s/step - loss: 0.3628 - accuracy: 0.8457 - val_loss: 0.3808 - val_accuracy: 0.8411
# Epoch 14/20
# 15/15 [==============================] - 174s 12s/step - loss: 0.3424 - accuracy: 0.8601 - val_loss: 0.4012 - val_accuracy: 0.8150
# Epoch 15/20
# 15/15 [==============================] - 165s 11s/step - loss: 0.3270 - accuracy: 0.8625 - val_loss: 0.4183 - val_accuracy: 0.8063
# Epoch 16/20
# 15/15 [==============================] - 179s 12s/step - loss: 0.3387 - accuracy: 0.8533 - val_loss: 0.3779 - val_accuracy: 0.8292
# Epoch 17/20
# 15/15 [==============================] - 167s 11s/step - loss: 0.3099 - accuracy: 0.8693 - val_loss: 0.3426 - val_accuracy: 0.8411
# Epoch 18/20
# 15/15 [==============================] - 163s 11s/step - loss: 0.2945 - accuracy: 0.8753 - val_loss: 0.3513 - val_accuracy: 0.8520
# Epoch 19/20
# 15/15 [==============================] - 130s 9s/step - loss: 0.3272 - accuracy: 0.8593 - val_loss: 0.4652 - val_accuracy: 0.7497
# Epoch 20/20
# 15/15 [==============================] - 117s 8s/step - loss: 0.3180 - accuracy: 0.8606 - val_loss: 0.3284 - val_accuracy: 0.8487

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = resnet.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 997us/step - loss: 0.2652 - accuracy: 0.9061
