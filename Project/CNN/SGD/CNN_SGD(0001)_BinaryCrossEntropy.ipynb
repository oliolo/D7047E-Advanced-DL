# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam, SGD

# %%
model = keras.Sequential()
model.add(InputLayer(input_shape=(150,150,3)))
model.add(Conv2D(filters=32,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())
model.add(Conv2D(filters=64,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())


model.add(Flatten())


model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(1, activation="sigmoid"))


model.compile(optimizer=SGD(0.0001),loss = BinaryCrossentropy(),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11214976
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 11,243,457
# Trainable params: 11,243,073
# Non-trainable params: 384
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = model.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 102s 7s/step - loss: 0.8432 - accuracy: 0.5243 - val_loss: 0.6862 - val_accuracy: 0.5800
# Epoch 2/20
# 15/15 [==============================] - 104s 7s/step - loss: 0.7557 - accuracy: 0.5849 - val_loss: 0.6769 - val_accuracy: 0.6518
# Epoch 3/20
# 15/15 [==============================] - 86s 6s/step - loss: 0.6932 - accuracy: 0.6319 - val_loss: 0.6696 - val_accuracy: 0.6355
# Epoch 4/20
# 15/15 [==============================] - 104s 7s/step - loss: 0.6677 - accuracy: 0.6506 - val_loss: 0.6636 - val_accuracy: 0.6028
# Epoch 5/20
# 15/15 [==============================] - 131s 9s/step - loss: 0.6432 - accuracy: 0.6680 - val_loss: 0.6591 - val_accuracy: 0.5898
# Epoch 6/20
# 15/15 [==============================] - 128s 9s/step - loss: 0.6087 - accuracy: 0.6808 - val_loss: 0.6538 - val_accuracy: 0.5778
# Epoch 7/20
# 15/15 [==============================] - 128s 9s/step - loss: 0.6070 - accuracy: 0.6887 - val_loss: 0.6491 - val_accuracy: 0.5822
# Epoch 8/20
# 15/15 [==============================] - 127s 8s/step - loss: 0.5794 - accuracy: 0.7063 - val_loss: 0.6454 - val_accuracy: 0.5832
# Epoch 9/20
# 15/15 [==============================] - 129s 9s/step - loss: 0.5751 - accuracy: 0.7177 - val_loss: 0.6420 - val_accuracy: 0.5724
# Epoch 10/20
# 15/15 [==============================] - 102s 7s/step - loss: 0.5551 - accuracy: 0.7237 - val_loss: 0.6387 - val_accuracy: 0.5843
# Epoch 11/20
# 15/15 [==============================] - 108s 7s/step - loss: 0.5384 - accuracy: 0.7354 - val_loss: 0.6349 - val_accuracy: 0.5952
# Epoch 12/20
# 15/15 [==============================] - 106s 7s/step - loss: 0.5369 - accuracy: 0.7411 - val_loss: 0.6365 - val_accuracy: 0.5832
# Epoch 13/20
# 15/15 [==============================] - 109s 7s/step - loss: 0.5171 - accuracy: 0.7498 - val_loss: 0.6305 - val_accuracy: 0.5952
# Epoch 14/20
# 15/15 [==============================] - 105s 7s/step - loss: 0.5098 - accuracy: 0.7479 - val_loss: 0.6257 - val_accuracy: 0.6007
# Epoch 15/20
# 15/15 [==============================] - 106s 7s/step - loss: 0.4979 - accuracy: 0.7569 - val_loss: 0.6170 - val_accuracy: 0.6115
# Epoch 16/20
# 15/15 [==============================] - 90s 6s/step - loss: 0.4951 - accuracy: 0.7596 - val_loss: 0.6091 - val_accuracy: 0.6202
# Epoch 17/20
# 15/15 [==============================] - 78s 5s/step - loss: 0.4750 - accuracy: 0.7832 - val_loss: 0.6078 - val_accuracy: 0.6159
# Epoch 18/20
# 15/15 [==============================] - 58s 4s/step - loss: 0.4701 - accuracy: 0.7772 - val_loss: 0.5997 - val_accuracy: 0.6311
# Epoch 19/20
# 15/15 [==============================] - 58s 4s/step - loss: 0.4676 - accuracy: 0.7794 - val_loss: 0.5927 - val_accuracy: 0.6376
# Epoch 20/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.4544 - accuracy: 0.7843 - val_loss: 0.5801 - val_accuracy: 0.6659

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = model.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 997us/step - loss: 0.5460 - accuracy: 0.6735
