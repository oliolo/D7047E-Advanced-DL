# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, SGD

# %%
model = keras.Sequential()
model.add(InputLayer(input_shape=(150,150,3)))
model.add(Conv2D(filters=32,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())
model.add(Conv2D(filters=64,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())


model.add(Flatten())


model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(1, activation="sigmoid"))


model.compile(optimizer=SGD(0.0001),loss = MeanSquaredError(),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11214976
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 11,243,457
# Trainable params: 11,243,073
# Non-trainable params: 384
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = model.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 128s 9s/step - loss: 0.2999 - accuracy: 0.5436 - val_loss: 0.2524 - val_accuracy: 0.4853
# Epoch 2/20
# 15/15 [==============================] - 129s 9s/step - loss: 0.2776 - accuracy: 0.5871 - val_loss: 0.2502 - val_accuracy: 0.5408
# Epoch 3/20
# 15/15 [==============================] - 126s 8s/step - loss: 0.2575 - accuracy: 0.6227 - val_loss: 0.2487 - val_accuracy: 0.5397
# Epoch 4/20
# 15/15 [==============================] - 125s 8s/step - loss: 0.2478 - accuracy: 0.6400 - val_loss: 0.2470 - val_accuracy: 0.5702
# Epoch 5/20
# 15/15 [==============================] - 127s 8s/step - loss: 0.2440 - accuracy: 0.6430 - val_loss: 0.2453 - val_accuracy: 0.5854
# Epoch 6/20
# 15/15 [==============================] - 106s 7s/step - loss: 0.2331 - accuracy: 0.6498 - val_loss: 0.2444 - val_accuracy: 0.5898
# Epoch 7/20
# 15/15 [==============================] - 105s 7s/step - loss: 0.2210 - accuracy: 0.6775 - val_loss: 0.2427 - val_accuracy: 0.6028
# Epoch 8/20
# 15/15 [==============================] - 106s 7s/step - loss: 0.2209 - accuracy: 0.6854 - val_loss: 0.2408 - val_accuracy: 0.6137
# Epoch 9/20
# 15/15 [==============================] - 106s 7s/step - loss: 0.2144 - accuracy: 0.6898 - val_loss: 0.2389 - val_accuracy: 0.6213
# Epoch 10/20
# 15/15 [==============================] - 105s 7s/step - loss: 0.2148 - accuracy: 0.6846 - val_loss: 0.2372 - val_accuracy: 0.6235
# Epoch 11/20
# 15/15 [==============================] - 105s 7s/step - loss: 0.2144 - accuracy: 0.6824 - val_loss: 0.2353 - val_accuracy: 0.6300
# Epoch 12/20
# 15/15 [==============================] - 84s 6s/step - loss: 0.2109 - accuracy: 0.6955 - val_loss: 0.2330 - val_accuracy: 0.6398
# Epoch 13/20
# 15/15 [==============================] - 71s 5s/step - loss: 0.2030 - accuracy: 0.7080 - val_loss: 0.2302 - val_accuracy: 0.6420
# Epoch 14/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.2035 - accuracy: 0.7074 - val_loss: 0.2283 - val_accuracy: 0.6464
# Epoch 15/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1967 - accuracy: 0.7142 - val_loss: 0.2260 - val_accuracy: 0.6496
# Epoch 16/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.2007 - accuracy: 0.7099 - val_loss: 0.2232 - val_accuracy: 0.6605
# Epoch 17/20
# 15/15 [==============================] - 36s 2s/step - loss: 0.1919 - accuracy: 0.7207 - val_loss: 0.2200 - val_accuracy: 0.6746
# Epoch 18/20
# 15/15 [==============================] - 35s 2s/step - loss: 0.1910 - accuracy: 0.7226 - val_loss: 0.2167 - val_accuracy: 0.6953
# Epoch 19/20
# 15/15 [==============================] - 35s 2s/step - loss: 0.1898 - accuracy: 0.7272 - val_loss: 0.2133 - val_accuracy: 0.6997
# Epoch 20/20
# 15/15 [==============================] - 35s 2s/step - loss: 0.1870 - accuracy: 0.7370 - val_loss: 0.2096 - val_accuracy: 0.7138

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("../../Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = model.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 995us/step - loss: 0.1895 - accuracy: 0.7469
