# %%
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from keras.preprocessing.image import ImageDataGenerator

# %%
gen = ImageDataGenerator(rescale=1./255,validation_split = 0.2,zoom_range=(0.99,0.99),dtype=tf.float32)

# %%
train = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")
                
val = gen.flow_from_directory("../../BrainTumor/Data/DataSet/",
                               target_size = (150,150),
                               batch_size = 8,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "validation")
classes = val.class_indices
# Out:
# Found 3681 images belonging to 2 classes.
# Found 919 images belonging to 2 classes.

# %%
classes
# Out:
# {'BrainTumor': 0, 'Healthy': 1}

# %%
t=0
h=0
for i in range(15):
    a, b = next(train)
    for j in b:
        if j == 1:
            h+=1
        else:t+=1

sns.barplot(x=['tumor','healty'],y=[t,h])
import matplotlib.pyplot as plt
batch = next(train)

plt.imshow(batch[0][0])

# %%
from keras.layers import Conv2D, MaxPool2D, LeakyReLU, BatchNormalization, Dropout, Dense, InputLayer, Flatten
from keras.losses import MeanSquaredError
from keras.optimizers import Adam, SGD

# %%
model = keras.Sequential()
model.add(InputLayer(input_shape=(150,150,3)))
model.add(Conv2D(filters=32,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())
model.add(Conv2D(filters=64,kernel_size=3, activation="relu", padding="same"))
model.add(MaxPool2D())


model.add(Flatten())


model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(64, activation="relu"))
model.add(BatchNormalization())
model.add(Dropout(rate=0.3))
model.add(Dense(1, activation="sigmoid"))


model.compile(optimizer=SGD(0.001),loss = MeanSquaredError(),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11214976
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 11,243,457
# Trainable params: 11,243,073
# Non-trainable params: 384
# _________________________________________________________________

# %%
from keras import utils, callbacks
earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                        patience=5, restore_best_weights = True)

# %%
history = model.fit(train,verbose=1,callbacks = [earlystopping],epochs=20,validation_data=(val))
# Out:
# Epoch 1/20
# 15/15 [==============================] - 59s 4s/step - loss: 0.2500 - accuracy: 0.6137 - val_loss: 0.2361 - val_accuracy: 0.7029
# Epoch 2/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1961 - accuracy: 0.7188 - val_loss: 0.2342 - val_accuracy: 0.7018
# Epoch 3/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1841 - accuracy: 0.7286 - val_loss: 0.2295 - val_accuracy: 0.7378
# Epoch 4/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1756 - accuracy: 0.7414 - val_loss: 0.2285 - val_accuracy: 0.7247
# Epoch 5/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1619 - accuracy: 0.7617 - val_loss: 0.2280 - val_accuracy: 0.7171
# Epoch 6/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1510 - accuracy: 0.7786 - val_loss: 0.2240 - val_accuracy: 0.7301
# Epoch 7/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1437 - accuracy: 0.7952 - val_loss: 0.2234 - val_accuracy: 0.6953
# Epoch 8/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1343 - accuracy: 0.8104 - val_loss: 0.2200 - val_accuracy: 0.6931
# Epoch 9/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1266 - accuracy: 0.8272 - val_loss: 0.2177 - val_accuracy: 0.6779
# Epoch 10/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1214 - accuracy: 0.8373 - val_loss: 0.2146 - val_accuracy: 0.7084
# Epoch 11/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1188 - accuracy: 0.8405 - val_loss: 0.2028 - val_accuracy: 0.7965
# Epoch 12/20
# 15/15 [==============================] - 56s 4s/step - loss: 0.1137 - accuracy: 0.8424 - val_loss: 0.2057 - val_accuracy: 0.7682
# Epoch 13/20
# 15/15 [==============================] - 58s 4s/step - loss: 0.1076 - accuracy: 0.8560 - val_loss: 0.2137 - val_accuracy: 0.6670
# Epoch 14/20
# 15/15 [==============================] - 58s 4s/step - loss: 0.1015 - accuracy: 0.8666 - val_loss: 0.1993 - val_accuracy: 0.7617
# Epoch 15/20
# 15/15 [==============================] - 57s 4s/step - loss: 0.1044 - accuracy: 0.8617 - val_loss: 0.1947 - val_accuracy: 0.8259
# Epoch 16/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0950 - accuracy: 0.8780 - val_loss: 0.1918 - val_accuracy: 0.8096
# Epoch 17/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0925 - accuracy: 0.8829 - val_loss: 0.1855 - val_accuracy: 0.8455
# Epoch 18/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0924 - accuracy: 0.8854 - val_loss: 0.1754 - val_accuracy: 0.8966
# Epoch 19/20
# 15/15 [==============================] - 55s 4s/step - loss: 0.0913 - accuracy: 0.8837 - val_loss: 0.1847 - val_accuracy: 0.8172
# Epoch 20/20
# 15/15 [==============================] - 54s 4s/step - loss: 0.0816 - accuracy: 0.8979 - val_loss: 0.1768 - val_accuracy: 0.8455

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
gen = ImageDataGenerator(rescale=1./255,zoom_range=(0.99,0.99),dtype=tf.float32)
test = gen.flow_from_directory("Test/DataSet/",
                               target_size = (150,150),
                               batch_size = 256,
                               class_mode = "binary",
                               color_mode = "rgb",
                               shuffle = True,
                               seed = 123,
                               subset = "training")

classes = val.class_indices
# Out:
# Found 245 images belonging to 2 classes.

# %%
_, acc  = model.evaluate(test, verbose=1)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.1780 - accuracy: 0.9102
